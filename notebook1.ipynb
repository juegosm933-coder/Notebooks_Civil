# %% [markdown]
# <a href="https://colab.research.google.com/github/juegosm933-coder/Notebooks_Civil/blob/main/notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CONTENIDOS
# 1. introduccion
# 2. objetivos
# 3. metodologia
# 4. analisis
# 5. ecuaciones

# %% [markdown]
# # introduccion
# jsbalgygayxbayxyhqcygHCBHJZBXHCEBCB<HCHJBV<JCGZYCYHDYCBCHIEFÑoufuHCF8UY80

# %% [markdown]
# # objetivos
#
# AHBDXJGCJYGLDCG<YJGCYGGS,JCYGYUGFYVilafuh<uh<chygyhhatdgfduuyvw

# %% [markdown]
# ## OBJETIVO GENERAL
#
# ABHCLYBCHUWIHAJDUIJ JFHDIUF9 GFHEIHHD8WYFIHIF TE AMO SAMUEL

# %% [markdown]
# ## OBJETIVO ESPECIFICO
# + PRIMER OBJETIVO: MELAAAAAAAAAAAAAAAAAAAA
# + SEGUNDO OBJETIVO: OlO
# + TERCER NIVEL
#
# MAJSDBHYXNUANJSUYSabsausdsdhs asyabsuhUSQUHASHASJQYa9QE te amo CARLOS

# %% [markdown]
# # ECUACIONES
#
# 1. ecuacion de la enrgia: $$E= m * c^2$$
#
# Todas las ecuaciones en formato laterx o markdowm se encuentran en el siguiente link
#
# [apuntes de latex](https://metodos.fam.cie.uva.es/~latex/apuntes/apuntes3.pdf)
